# %%
import pandas as pd
import numpy as np

# %%
room_check = pd.read_csv("RoomCheck.csv", encoding="latin1", na_values = ["PC not provided", "Verify", "Verify S/N", "None", "No Inventory #"]);
projector_list = pd.read_csv("ProjectorList.csv", encoding="latin1", na_values = ["PC not provided", "Verify", "Verify S/N", "None", "No Inventory #"])
computer_list = pd.read_csv("ComputerList.csv", encoding="latin1", na_values = ["PC not provided", "Verify", "Verify S/N", "None", "No Inventory #"])

# %%
room_check = room_check[["Location", "Lamp Hrs", "Lamp Hours(2)", "Projector Type", "Filter Hrs","Last Checked", "Model: Control | TP", "IP: Control | TP \xa0", "FW: Control | TP", "AMX IP", "Notes"]]

# %%
room_check.columns
# Out:
# Index(['Location', 'Lamp Hrs', 'Lamp Hours(2)', 'Projector Type', 'Filter Hrs',
#        'Last Checked', 'Model: Control | TP', 'IP: Control | TP  ',
#        'FW: Control | TP', 'AMX IP', 'Notes'],
#       dtype='object')

# %%
value = ["Location", "Lamp Hours(1)", "Lamp Hours(2)", "Projector Type", "Filter Hours", "Last Checked", "Control Model", "Control IP", "Control FW", "AMX IP", "Notes"]

# %%
room_check.rename(columns = dict(zip(room_check.columns, value)), inplace = True)

# %%
# dict(zip(room_check.columns, value))

# %%
room_check = room_check.loc[room_check["Location"].notnull(), :]

# %%
room_check.shape
# Out:
# (146, 11)

# %%
computer_list = computer_list.loc[computer_list["Location"].notnull(), :]

# %%
computer_list.shape
# Out:
# (181, 13)

# %%
computer_list.head()
# Out:
#   Location Classification   Type                                 OS:  \
# 0  RBN3047            NaN    NaN                   (CT Storage Room)
# 1   ARC141            220  Class  MacOS High Sierra Version 10.13.6
# 2  RBS1019             RL     RL                               No PC
# 3   CAS210            110  Class                                 NaN
# 4   CAS258            110  Class                                 NaN
#
#                   Model #   Service Tag       Warranty Satus Purchase Date  \
# 0      Dell Inspiron 2200       FHVVS81                  NaN           NaN
# 1   21.5", Late 2013 iMac  C02MLMWQF8J2    Warranty Expired            NaN
# 2                     NaN           NaN                  NaN           NaN
# 3  HP EliteDesk 800G1 SFF    MXL551117K  End Date: 1/12/2019     5/25/2011
# 4  HP EliteDesk 800G1 SFF    MXL551117M  End Date: 1/12/2019           NaN
#
#   Mfg. Date                      UTT Tag    Computer Name  \
# 0       NaN   Black: 15537 White: 015537  L-RBN3047-CONFE
# 1       NaN   Black: 22705 White: 022980      M-CL-ARC141
# 2       NaN                          NaN              NaN
# 3       NaN  Black: 24589 White: 025238      CL-CAS210-HP
# 4       NaN   Black: 24592 White: 025241     CL-CAS258-HP
#
#                           Notes Notes2
# 0               L-RBN3047-CONFE    NaN
# 1  iMac furninshed by Art Dept.    NaN
# 2                           NaN    NaN
# 3                           NaN    NaN
# 4                           NaN    NaN

# %%
computer_list = computer_list[["Location", "OS:", "Model #", "Service Tag", "Warranty Satus", "Purchase Date", "Mfg. Date", "UTT Tag", "Computer Name"]]

# %%
value = ["Location", "OS", "Computer Model", "Computer Service Tag", "Computer Warranty Satus", "Comuter Purchase Date", "Computer Mfg Date", "Computer UTT Tag", "Computer Name"]

# %%
computer_list.rename(columns = dict(zip(computer_list.columns, value)), inplace = True)

# %%
computer_list.head()
# Out:
#   Location                                  OS          Computer Model  \
# 0  RBN3047                   (CT Storage Room)      Dell Inspiron 2200
# 1   ARC141  MacOS High Sierra Version 10.13.6    21.5", Late 2013 iMac
# 2  RBS1019                               No PC                     NaN
# 3   CAS210                                 NaN  HP EliteDesk 800G1 SFF
# 4   CAS258                                 NaN  HP EliteDesk 800G1 SFF
#
#   Computer Service Tag Computer Warranty Satus Comuter Purchase Date  \
# 0              FHVVS81                     NaN                   NaN
# 1         C02MLMWQF8J2       Warranty Expired                    NaN
# 2                  NaN                     NaN                   NaN
# 3           MXL551117K     End Date: 1/12/2019             5/25/2011
# 4           MXL551117M     End Date: 1/12/2019                   NaN
#
#   Computer Mfg Date             Computer UTT Tag    Computer Name
# 0               NaN   Black: 15537 White: 015537  L-RBN3047-CONFE
# 1               NaN   Black: 22705 White: 022980      M-CL-ARC141
# 2               NaN                          NaN              NaN
# 3               NaN  Black: 24589 White: 025238      CL-CAS210-HP
# 4               NaN   Black: 24592 White: 025241     CL-CAS258-HP

# %%
projector_list.head()
# Out:
#   Location Classification               Model #              UT Tag  \
# 0   ALH108            NaN                   NaN                 NaN
# 1   ALH113            NaN                   NaN                 NaN
# 2   ARC112            110        NEC NP-PA803UL  White Only: 030150
# 3   ARC114            220  Panasonic PT-VZ575N                  NaN
# 4   ARC141            220           Epson 4750W                 NaN
#
#   Serial Number Manuf. Date  Purchase Date                             Notes  \
# 0           NaN         NaN            NaN                               NaN
# 1           NaN         NaN            NaN                               NaN
# 2     8900119RR         NaN            NaN                               NaN
# 3     DC6640296         NaN            NaN  Verify  Model, Inv. & Serial  #s
# 4   TL8F450119L         NaN            NaN                               NaN
#
#   IP Address
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
room_check.loc[room_check["Lamp Hours(2)"]== 0, "Lamp Hours(2)"] = np.nan

# %%
room_check["Lamp Hours(2)"].isnull().sum()
# Out:
# 124

# %%
rooms = computer_list.join(room_check.set_index("Location"), on = "Location")

# %%
rooms
# Out:
#         Location                                                 OS  \
# 0        RBN3047                                  (CT Storage Room)
# 1         ARC141                 MacOS High Sierra Version 10.13.6
# 2        RBS1019                                              No PC
# 3         CAS210                                                NaN
# 4         CAS258                                                NaN
# 5         CAS259                                                NaN
# 6         CAS260                                                NaN
# 7         BEP224                                                NaN
# 8         HPR132                                                NaN
# 9         HPR145                                                NaN
# 10        HPR146                                                NaN
# 11        HPR261                                                NaN
# 12        LIB401                                                NaN
# 13       RBN1034                                                NaN
# 14       RBN3032                                                NaN
# 15       BRB2040                                                NaN
# 16        STE301                                                NaN
# 17       HPC3055      Win10(x64) Version 1703 (OS Build 15063.1088)
# 18       BRB2405    Win10(x64) Version 1709 (OS Build 16299.1087)
# 19       BRB2410    Win10(x64) Version 1709 (OS Build 16299.1087)
# 20      FAC1222        Win10(x64) Version 1709 (OS Build 16299.371)
# 21       RBN2028  Win10(x64) Version 1709 (OS Build 16299.371) 1...
# 22        ARC112       Win10(x64) Version 1709 (OS Build 16299.431)
# 23       FAC1009       Win10(x64) Version 1709 (OS Build 16299.431)
# 24        HPR135       Win10(x64) Version 1709 (OS Build 16299.431)
# 25       RBN1039       Win10(x64) Version 1709 (OS Build 16299.547)
# 26       RBN2032       Win10(x64) Version 1709 (OS Build 16299.547)
# 27       RBN2046       Win10(x64) Version 1709 (OS Build 16299.547)
# 28       RBN3038       Win10(x64) Version 1709 (OS Build 16299.547)
# 29       RBN3039       Win10(x64) Version 1709 (OS Build 16299.547)
# ..           ...                                                ...
# 151      RBN4025                            Win10(X64) Version 1809
# 152      RBN4032                            Win10(X64) Version 1809
# 153      RBN4034                            Win10(X64) Version 1809
# 154      BRB2490  Win7(x64) Version 6.1 (Build 7601: Service Pac...
# 155      HPC3035  Win7(x64) Version 6.1 (Build 7601: Service Pac...
# 156       HPR235  Win7(x64) Version 6.1 (Build 7601: Service Pac...
# 157       LIB202  Win7(x64) Version 6.1 (Build 7601: Service Pac...
# 158      RBN1007  Win7(x64) Version 6.1 (Build 7601: Service Pac...
# 159      RBN4039  Win7(x64) Version 6.1 (Build 7601: Service Pac...
# 160      RBS1024  Win7(x64) Version 6.1 (Build 7601: Service Pac...
# 161      RBS1032  Win7(x64) Version 6.1 (Build 7601: Service Pac...
# 162      RBS2023  Win7(x64) Version 6.1 (Build 7601: Service Pac...
# 163       STE324  Win7(x64) Version 6.1 (Build 7601: Service Pac...
# 164       HPR256      Wind10(x64) Version 1803 (OS Build 17134.472)
# 165          ALH                                                NaN
# 166       BEP128                                                NaN
# 167       BEP129                                                NaN
# 168       BEP132                                                NaN
# 169       BEP133                                                NaN
# 170      BRB2495                                                NaN
# 171       CAS106                                                NaN
# 172       CAS158                                                NaN
# 173      HPC2185                                                NaN
# 174   SPARE CL 1                                                NaN
# 175  UC Ballroom                                                NaN
# 176   UC Theater                                                NaN
# 177      UC3114A                                                NaN
# 178      UC3114B                                                NaN
# 179     UC Audit                                                NaN
# 180     UCN Ball                                                NaN
#
#                        Computer Model Computer Service Tag  \
# 0                  Dell Inspiron 2200              FHVVS81
# 1               21.5", Late 2013 iMac         C02MLMWQF8J2
# 2                                 NaN                  NaN
# 3              HP EliteDesk 800G1 SFF           MXL551117K
# 4              HP EliteDesk 800G1 SFF           MXL551117M
# 5              HP EliteDesk 800G1 SFF           MXL551117D
# 6              HP EliteDesk 800G1 SFF           MXL4340C86
# 7              HP EliteDesk 800G1 SFF           MXL4340C91
# 8                                 NaN                  NaN
# 9                                 NaN                  NaN
# 10                                NaN                  NaN
# 11                                NaN                  NaN
# 12                                NaN                  NaN
# 13                                NaN                  NaN
# 14                                NaN                  NaN
# 15                                NaN              DKNLRD1
# 16             HP EliteDesk 800G1 SFF                  NaN
# 17             HP EliteDesk 800G1 SFF           MXL4340C88
# 18                 Dell Optiplex 7020              H27SD22
# 19                 Dell Optiplex 7020              G75XD22
# 20            HP EliteDesk 800 G1 SFF          MXL4340C8K
# 21             HP EliteDesk 800G1 SFF           MXL4340C97
# 22             HP EliteDesk 800G1 SFF           MXL4340C9Y
# 23             HP EliteDesk 800G1 SFF           MXL4340C9C
# 24             HP EliteDesk 800G1 SFF           MXL551117N
# 25             HP EliteDesk 800G1 SFF           MXL4340CB3
# 26   Dell Optiplex 745 (will replace)              3RX4XD1
# 27             HP EliteDesk 800G1 SFF           MXL4340C9L
# 28             HP EliteDesk 800G1 SFF           MXL4340C85
# 29             HP EliteDesk 800G1 SFF           MXL4340C8V
# ..                                ...                  ...
# 151            HP EliteDesk 800G1 SFF           MXL5511173
# 152                Dell Optiplex 7020             5B7SD22
# 153                Dell Optiplex 7020             477SD22
# 154                Dell Optiplex 7010              FYSGHX1
# 155            HP EliteDesk 800G1 SFF                  NaN
# 156                 Dell Optiplex 380              5FVKJM1
# 157                 Dell Optiplex 755                  NaN
# 158            HP EliteDesk 800G1 SFF           MXL4340C8Y
# 159                Dell Optiplex 3020              JSHDX12
# 160                Dell Optiplex 3010              4FGH7Y1
# 161            HP EliteDesk 800G1 SFF                  NaN
# 162                 Dell Optiplex 390              CW0QNS1
# 163            HP EliteDesk 800G2 SFF          MXL6352NXQ
# 164            HP EliteDesk 800G1 SFF           MXL4340C8C
# 165                               NaN                  NaN
# 166                               NaN                  NaN
# 167                               NaN                  NaN
# 168                               NaN                  NaN
# 169                 Dell Optiplex 380               HHCKM1
# 170                Dell Optiplex 7010                  NaN
# 171            HP EliteDesk 800G1 SFF           MXL4340C85
# 172                               NaN                  NaN
# 173                               NaN                  NaN
# 174                Dell Optiplex 7020              GB7SD22
# 175            HP EliteDesk 800G1 SFF                  NaN
# 176            HP EliteDesk 800G1 SFF                  NaN
# 177                 Dell Optiplex 380              4CC04V1
# 178                 Dell Optiplex 390              404QTV1
# 179            HP EliteDesk 800G1 SFF              FYDWFK1
# 180                          LATITUDE              5FW6MQ1
#
#     Computer Warranty Satus Comuter Purchase Date Computer Mfg Date  \
# 0                       NaN                   NaN               NaN
# 1         Warranty Expired                    NaN               NaN
# 2                       NaN                   NaN               NaN
# 3       End Date: 1/12/2019             5/25/2011               NaN
# 4       End Date: 1/12/2019                   NaN               NaN
# 5       End Date: 1/12/2019             5/25/2011               NaN
# 6         Warranty Expired              5/25/2011               NaN
# 7         Warranty Expired                    NaN               NaN
# 8                       NaN                   NaN               NaN
# 9                       NaN                   NaN               NaN
# 10                      NaN                   NaN               NaN
# 11                      NaN                   NaN               NaN
# 12                      NaN                   NaN               NaN
# 13                      NaN                   NaN               NaN
# 14                      NaN                   NaN               NaN
# 15                      NaN                   NaN               NaN
# 16                      NaN                   NaN               NaN
# 17        Warranty Expired                    NaN               NaN
# 18                      NaN                   NaN               NaN
# 19                      NaN                   NaN               NaN
# 20                      NaN                   NaN               NaN
# 21        Warranty Expired                    NaN               NaN
# 22        Warranty Expired                    NaN               NaN
# 23        Warranty Expired                    NaN               NaN
# 24      End Date: 1/12/2019             5/25/2011               NaN
# 25                      NaN                   NaN               NaN
# 26                      NaN                   NaN               NaN
# 27        Warranty Expired                    NaN               NaN
# 28                      NaN                   NaN               NaN
# 29                      NaN                   NaN               NaN
# ..                      ...                   ...               ...
# 151     End Date: 1/12/2019                   NaN               NaN
# 152                     NaN                   NaN               NaN
# 153                     NaN                   NaN               NaN
# 154                     NaN                   NaN               NaN
# 155                     NaN                   NaN               NaN
# 156                     NaN                   NaN               NaN
# 157                     NaN                   NaN               NaN
# 158       Warranty Expired                    NaN               NaN
# 159                     NaN                   NaN          20140805
# 160                     NaN                   NaN               NaN
# 161                     NaN                   NaN               NaN
# 162                     NaN                   NaN          20120430
# 163     End Date: 9/06/2019                   NaN               NaN
# 164                     NaN                   NaN               NaN
# 165                     NaN                   NaN               NaN
# 166                     NaN                   NaN               NaN
# 167                     NaN                   NaN               NaN
# 168                     NaN                   NaN               NaN
# 169       Warranty Expired                    NaN        2010.06.17
# 170                     NaN                   NaN               NaN
# 171       Warranty Expired                    NaN               NaN
# 172                     NaN                   NaN               NaN
# 173                     NaN                   NaN               NaN
# 174                     NaN                   NaN               NaN
# 175                     NaN                   NaN               NaN
# 176                     NaN                   NaN               NaN
# 177                     NaN                   NaN               NaN
# 178                     NaN                   NaN               NaN
# 179                     NaN                   NaN               NaN
# 180                     NaN                   NaN               NaN
#
#                    Computer UTT Tag    Computer Name Lamp Hours(1)  \
# 0        Black: 15537 White: 015537  L-RBN3047-CONFE          1089
# 1        Black: 22705 White: 022980      M-CL-ARC141           108
# 2                               NaN              NaN           NaN
# 3       Black: 24589 White: 025238      CL-CAS210-HP          1352
# 4        Black: 24592 White: 025241     CL-CAS258-HP           NaN
# 5        Black: 24593 White: 025242     CL-CAS259-HP           NaN
# 6                      Black: 23015    CL-CAS260-HPX           NaN
# 7        Black: 23036 White: 023163     BEP224-SCAN2           NaN
# 8                               NaN              NaN     (PC Only)
# 9                               NaN              NaN           NaN
# 10                              NaN              NaN  Old/Not used
# 11                Black Only: 23043     CL-HPR261-HP           454
# 12                              NaN              NaN          1075
# 13                              NaN              NaN           NaN
# 14                              NaN              NaN     (PC Only)
# 15                              NaN       CL-BRB2040           NaN
# 16                Black Only: 23044     CL-STE301-HP           382
# 17               Black: Only: 23039    CL-HPC3055-HP          1419
# 18                White Only: 27046       CL-BRB2405           800
# 19               White Only: 27047        CL-BRB2410           737
# 20       Black: 23034 White: 027328    CL-FAC1222-HP           NaN
# 21                Black Only: 23030    CL-RBN2028-HP          3163
# 22       Black: 23003 White: 023192     CL-ARC112-HP           268
# 23       Black: 23007 White: 023196    CL-FAC1009-HP           841
# 24       Black: 24572 White: 025225     CL-HPR135-HP          3493
# 25                Black Only: 23002     CLHP-RBN1039           632
# 26   Black: 16907 and White: 016907       CL-RBN2032          3162
# 27   Black: 23026 and White: 027076    CL-RBN2046-HP            81
# 28                Black only: 23016    CL-RBN3038-HP          2036
# 29   Black: 23018 and White: 023145    CL-RBN3039-HP          3467
# ..                              ...              ...           ...
# 151  Black: 24582 and White: 025232    CL-RBN4025-HP          4424
# 152             White Only: 027036   CL-RBN4032-DELL          2449
# 153              White Only: 027037  CL-RBN4034-DELL             2
# 154  Black Only: 22105 White: 22105     DT-BRBEMSDB1          1228
# 155               Black Only: 23005    CL-HPC3035-HP           110
# 156      Black: 19391 White: 019391      HPR235-CONF           744
# 157               Black Only: 18362              NaN     (Display)
# 158               Black Only: 23046    CL-RBN1007-HP          2195
# 159               Black Only: 22800     RBN4039-CONF          1083
# 160      Black: 22157 White: 022157       CL-RBS1024           277
# 161               Black Only: 23010    CL-RBS1032-HP     (PC Only)
# 162      Black: 19862 White: 019862       CL-RBS2023           162
# 163               Black Only: 25394    STE324-PRCONF            TV
# 164      Black: 23017 White: 029391     CL-HPR256-HP          3601
# 165                             NaN              NaN           NaN
# 166                             NaN              NaN          4648
# 167                             NaN              NaN           847
# 168                             NaN              NaN          3535
# 169      Black: 19246 White: 019246     BEP133-LAB04           NaN
# 170               Black Only: 22107              NaN           318
# 171               Black Only: 23016    CL-CAS106-HPX           NaN
# 172                             NaN              NaN             0
# 173                             NaN              NaN          1071
# 174              White Only: 027040     CL-CTSPARE-1           NaN
# 175               Black Only: 23022     CL-UCAUDI-HP           NaN
# 176               Black Only: 24148     UC3413-24148           NaN
# 177               Black Only: 19882       CL-UC3114A           NaN
# 178     Black: 21289 White: 021289        CL-UC3114B           NaN
# 179               Black Only: 23051     CL-UCBALL-HP           NaN
# 180               Black Only: 23022  L-UC3400-CHECK3           NaN
#
#     Lamp Hours(2)         Projector Type   Filter Hours Last Checked  \
# 0             NaN            Epson 6100i              0          NaN
# 1             NaN            Epson 4750W              0     6/4/2019
# 2             NaN                    NaN            NaN          NaN
# 3             NaN     Panasonic PT-VZ575            163    7/21/2017
# 4             NaN                    NaN            145          NaN
# 5             NaN                    NaN              0
# 6             NaN                    NaN              0
# 7             NaN                    NaN            NaN          NaN
# 8             NaN                    NaN            NaN            ?
# 9             NaN                    NaN            NaN          NaN
# 10            NaN             3M MP-8670              ?    5/26/2015
# 11            NaN            Epson 6100i    0 (Was 136)     6/7/2018
# 12            NaN            Epson 6110i            380     5/2/2017
# 13            NaN                    NaN            NaN          NaN
# 14            NaN              (PC Only)            NaN            ?
# 15            NaN                    NaN            NaN          NaN
# 16            NaN     Panasonic PT-EZ590            373    8/23/2017
# 17            NaN  NEC NP-P502WL-2 Laser              0    4/12/2019
# 18            NaN    Panasonic PT-VZ575N            238    5/17/2019
# 19            NaN    Panasonic PT-VZ575N            144    5/17/2019
# 20            NaN                    NaN            NaN          NaN
# 21            NaN            Epson 6100i              0    11/5/2018
# 22            NaN         NEC NP-PA803UL  Self Cleaning     6/4/2019
# 23            NaN            Epson G5350              0    4/12/2019
# 24            NaN    Panasonic PT-VZ575N              0    5/15/2019
# 25            NaN            Epson 6100i              0    7/31/2018
# 26            NaN            Epson 6100i              0    7/31/2018
# 27            NaN            Epson 6100i             10    1/10/2018
# 28              0    Panasonic PT-VZ575N              0          NaN
# 29            NaN    Panasonic PT-VZ575N              0          NaN
# ..            ...                    ...            ...          ...
# 151           NaN     Panasonic PT-VZ575              0          NaN
# 152           NaN        NEC NP-P502WL-2              0    6/19/2019
# 153           NaN        NEC NP-P502WL-2              0          NaN
# 154           NaN              SmartUX80            515    5/17/2019
# 155           NaN            Epson 6110i            110    2/20/2018
# 156           NaN            Epson 6100i            169    5/15/2019
# 157           NaN                    NaN            NaN            ?
# 158           NaN            Epson 6100i            251    8/22/2017
# 159           NaN            Epson 6100i             14          NaN
# 160           NaN             Smart 60WI              0          NaN
# 161           NaN              (PC Only)            NaN            ?
# 162           NaN   Epson PowerLite 965H              0    8/24/2017
# 163           NaN              (Display)            NaN    8/16/2017
# 164           NaN     Panasonic PT-VZ575              0     1/8/2019
# 165           NaN                    NaN            NaN          NaN
# 166           NaN    Panasonic PT-VZ575N            150    5/13/2019
# 167           NaN    Panasonic PT-VZ575N            902    5/13/2019
# 168           NaN    Panasonic PT-VZ575N            956    5/13/2019
# 169           NaN                    NaN            NaN          NaN
# 170           NaN              SmartUX80            318     8/2/2016
# 171           NaN                    NaN            NaN
# 172           NaN             Epson 4300              0
# 173           NaN            Epson 4200W            NaN    7/27/2018
# 174           NaN                    NaN            NaN          NaN
# 175           NaN                    NaN            NaN          NaN
# 176           NaN                    NaN            NaN          NaN
# 177           NaN                    NaN            NaN          NaN
# 178           NaN                    NaN            NaN          NaN
# 179           NaN                    NaN            NaN          NaN
# 180           NaN                    NaN            NaN          NaN
#
#                 Control Model      Control IP  \
# 0                  QM-RMCRXBA   192.168.71.58
# 1               AMX Wallplate             NaN
# 2                         NaN             NaN
# 3                      QM-RMC  192.168.80.128
# 4                      QM-RMC   192.168.80.64
# 5                      QM-RMC   192.168.80.29
# 6                      QM-RMC   192.168.80.58
# 7                         NaN             NaN
# 8                         NaN             NaN
# 9                         NaN             NaN
# 10                        NaN             NaN
# 11                        NaN             NaN
# 12                        NaN             NaN
# 13                        NaN             NaN
# 14                        NaN             NaN
# 15                        NaN             NaN
# 16                DMPS3-300-C   192.168.80.44
# 17                DMPS3-200-C  192.168.80.161
# 18                        NaN             NaN
# 19                   XPA 2001             NaN
# 20                        NaN             NaN
# 21                    MPS-100  192.168.80.169
# 22   DMPS3-4K-100-C | TSW-760  192.168.80.148
# 23             DMPS3-4K-150-C  192.168.80.152
# 24             DMPS3-4K-100-C  192.168.80.134
# 25                        NaN             NaN
# 26                    MPS-100   192.168.71.11
# 27                    MPS-100    192.168.71.6
# 28             DMPS3-4K-150-C     10.20.14.10
# 29             DMPS3-4K-150-C     10.20.14.13
# ..                        ...             ...
# 151            DMPS3-4K-150-C  192.168.80.174
# 152            DMPS3-4K-150-C  192.168.80.155
# 153                   MPS-100     10.20.14.28
# 154                       NaN             NaN
# 155                       NaN             NaN
# 156                       NaN             NaN
# 157                       NaN             NaN
# 158                       NaN             NaN
# 159                QM-RMCRXBA   192.168.71.13
# 160                       NaN             NaN
# 161                       NaN             NaN
# 162                   MPS-100   192.168.80.42
# 163               DMPS3-200-C   192.168.80.35
# 164                       NaN             NaN
# 165                       NaN             NaN
# 166                       NaN             NaN
# 167                       NaN             NaN
# 168                       NaN             NaN
# 169                       NaN             NaN
# 170                    QM-RMC  192.168.80.171
# 171                       NaN             NaN
# 172                   MPS-100   192.168.80.62
# 173                    MPC-M5   192.168.80.80
# 174                       NaN             NaN
# 175                       NaN             NaN
# 176                       NaN             NaN
# 177                       NaN             NaN
# 178                       NaN             NaN
# 179                       NaN             NaN
# 180                       NaN             NaN
#
#                                     Control FW          AMX IP  \
# 0                                          NaN             NaN
# 1                                          NaN  192.168.80.132
# 2                                          NaN             NaN
# 3                     4.008.0008 (Oct 22 2013)             NaN
# 4                     4.008.0008 (Oct 22 2013)             NaN
# 5                     4.008.0008 (Oct 22 2013)             NaN
# 6                     4.008.0008 (Oct 22 2013)             NaN
# 7                                          NaN             NaN
# 8                                          NaN             NaN
# 9                                          NaN             NaN
# 10                                         NaN             NaN
# 11                                         NaN             NaN
# 12                                         NaN             NaN
# 13                                         NaN             NaN
# 14                                         NaN             NaN
# 15                                         NaN             NaN
# 16                            1.501.2843.20911             NaN
# 17                            1.502.3175.21489             NaN
# 18                                         NaN             NaN
# 19                                         NaN             NaN
# 20                                         NaN             NaN
# 21   Current Version: 4.003.0015 (Oct 04 2010)             NaN
# 22              1.502.3205.17254 (Oct 11 2017)             NaN
# 23                            1.502.3088.20962             NaN
# 24                                         NaN             NaN
# 25                                         NaN             NaN
# 26                                         NaN             NaN
# 27                                         NaN             NaN
# 28           Current Version: 1.501.2958.31007             NaN
# 29           Current Version: 1.502.3175.24468             NaN
# ..                                         ...             ...
# 151          Current Version: 1.501.2958.31007             NaN
# 152  Current Version: 4.003.0015 (Oct 04 2010)             NaN
# 153  Current Version: 4.003.0015 (Oct 04 2010)             NaN
# 154                                        NaN             NaN
# 155                                        NaN             NaN
# 156                                        NaN             NaN
# 157                                        NaN             NaN
# 158                                        NaN             NaN
# 159                                        NaN             NaN
# 160                                        NaN             NaN
# 161                                        NaN             NaN
# 162  Current Version: 4.003.0015 (Oct 04 2010)             NaN
# 163                           1.502.3081.24394             NaN
# 164                                        NaN             NaN
# 165                                        NaN             NaN
# 166                                        NaN             NaN
# 167                                        NaN             NaN
# 168                                        NaN             NaN
# 169                                        NaN             NaN
# 170                   4.008.0008 (Oct 22 2013)             NaN
# 171                                        NaN             NaN
# 172                   4.003.0015 (Oct 04 2010)             NaN
# 173                                        NaN             NaN
# 174                                        NaN             NaN
# 175                                        NaN             NaN
# 176                                        NaN             NaN
# 177                                        NaN             NaN
# 178                                        NaN             NaN
# 179                                        NaN             NaN
# 180                                        NaN             NaN
#
#                                                  Notes
# 0    System- This room has less in it than others, ...
# 1               System- \nComponents: AMX Wallplate |
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11   System- This room has less components than mos...
# 12   System- \nComponents: AMX NXT-CV10 Touchpanel(...
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17   System- \nComponents: Crestron TSW-750-TTK-B-S...
# 18   System- This skills lab has less system compon...
# 19   System- This skills lab has less system compon...
# 20                                                 NaN
# 21   System- \nComponents: Crestron Touchpanel and ...
# 22   System- \nComponents: Crestron TSW-760-TTK-B-S...
# 23   System- \nComponents: Crestron TSW-760-TTK-B-S...
# 24   System- \nComponents: \nCrestron- \n? TSW-760-...
# 25   System- \nComponents: Crestron TPS-3000 Touchp...
# 26   System-\nComponents:Crestron TPS-3000 touchpan...
# 27   System- \nComponents: Crestron TPS-3000 Touchp...
# 28   System- \nComponents: Crestron Touchpanel and ...
# 29   System- \nComponents: Crestron DMPS3-300-C and...
# ..                                                 ...
# 151  System- \nComponents: Crestron TSW-750-TTK-B-S...
# 152  System- \nComponents: \nCrestron \n? TSW-750-T...
# 153  System- \nComponents: Crestron MPS-100(Inv. #:...
# 154  System Functionality: \nAll system components ...
# 155                                                NaN
# 156  System- The system in this room is minimal \nC...
# 157                                                NaN
# 158  System- \nComponents: Crestron TPS-3000 Touchp...
# 159  System- \nComponents: Crestron wallplate touch...
# 160  System- \nComponents: AMX wallplate style touc...
# 161                                                NaN
# 162  System- \nComponents: Crestron TSW-750-TTK-B-S...
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166  System- \nComponents: Crestron HD-RX-201-C-E (...
# 167  System- \nComponents: Crestron HD-RX-201-C-E (...
# 168  System- \nComponents: Crestron Wallplate, Proj...
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
#
# [181 rows x 19 columns]
